# %% [markdown]
# ![image.png](attachment:image.png)

# %%
palavras <- c('Melancia', 'Banana', 'Abacaxi','Morango','Goiaba')
visualizacao <- sample(palavras, 1000, replace=TRUE)
visualizacao
# Out:
#    [1] "Morango"  "Morango"  "Banana"   "Morango"  "Abacaxi"  "Abacaxi"
#    [7] "Goiaba"   "Goiaba"   "Melancia" "Morango"  "Morango"  "Goiaba"
#   [13] "Banana"   "Goiaba"   "Melancia" "Melancia" "Banana"   "Goiaba"
#   [19] "Morango"  "Banana"   "Goiaba"   "Morango"  "Goiaba"   "Goiaba"
#   [25] "Melancia" "Melancia" "Morango"  "Banana"   "Morango"  "Banana"
#   [31] "Banana"   "Banana"   "Melancia" "Abacaxi"  "Morango"  "Morango"
#   [37] "Goiaba"   "Banana"   "Goiaba"   "Morango"  "Goiaba"   "Melancia"
#   [43] "Goiaba"   "Abacaxi"  "Abacaxi"  "Morango"  "Morango"  "Banana"
#   [49] "Melancia" "Goiaba"   "Goiaba"   "Abacaxi"  "Banana"   "Morango"
#   [55] "Abacaxi"  "Abacaxi"  "Goiaba"   "Morango"  "Morango"  "Morango"
#   [61] "Abacaxi"  "Melancia" "Melancia" "Morango"  "Melancia" "Goiaba"
#   [67] "Abacaxi"  "Morango"  "Morango"  "Morango"  "Banana"   "Morango"
#   [73] "Melancia" "Abacaxi"  "Banana"   "Morango"  "Melancia" "Morango"
# ...

# %%
table(visualizacao)
# Out:
# visualizacao
#  Abacaxi   Banana   Goiaba Melancia  Morango
#      201      202      211      187      199

# %%
barplot(table(visualizacao))
# Out:
# plot without title

# %%
pie(c(201,202,211,187,199))
# Out:
# plot without title

# %%
y <-c(201,202,211,187,199)
x <-1:5
plot(x,y)
# Out:
# plot without title
